# %% [markdown]
# <a href="https://colab.research.google.com/github/nathaliacastelobranco/infnet-infraestrutura-hadoop/blob/main/ELT_CAGED_Hadoop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ETL CAGED

# %%
# !pip install py7zr pyarrow google-cloud-storage -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.0/97.0 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.7/51.7 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.7/142.7 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.6/413.6 kB 19.7 MB/s eta 0:00:00

# %%
# ========================================
# 1. Dependências e autenticação
# ========================================
import os
import shutil
import py7zr
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
from ftplib import FTP
from google.cloud import storage

from google.colab import auth
auth.authenticate_user()

# %%
# ========================================
# 2. Configurações
# ========================================
FTP_HOST='ftp.mtps.gov.br'
FTP_BASE_PATH = "pdet/microdados/NOVO CAGED"
BASE_PATH = "/content/caged_data"
BUCKET_NAME = "bucket_caged"

anos = [2020, 2021, 2022, 2023, 2024, 2025]
tipos = ["MOV", "EXC", "FOR"]

os.makedirs(BASE_PATH, exist_ok=True)

# %%
# ========================================
# 3. Funções auxiliares
# ========================================
def baixar_arquivos(ano, mes):
    """
    Baixa todos os .7z da pasta do mês (retorna lista de paths locais).
    """
    baixados = []
    path = f"{FTP_BASE_PATH}/{ano}/{ano}{mes:02d}"
    try:
        with FTP(FTP_HOST, user="anonymous", passwd="aaaaa", encoding="latin-1") as ftp:
            try:
                ftp.cwd(path)
            except Exception as e:
                print(f"[WARN] Pasta não encontrada: {path}")
                return []
            files = ftp.nlst()
            for f in files:
                if f.lower().endswith(".7z"):
                    local_file = os.path.join(BASE_PATH, f)
                    if not os.path.exists(local_file):
                        print(f"Baixando {f} ...")
                        with open(local_file, "wb") as lf:
                            ftp.retrbinary(f"RETR {f}", lf.write)
                    else:
                        print(f"Já existe localmente: {f}")
                    baixados.append(local_file)
    except Exception as e:
        print(f"[ERRO FTP] {e}")
    return baixados

def extrair_7z_para_pasta(arquivo_7z, out_dir):
    """
    Extrai o .7z para uma pasta própria (evita conflito de nomes).
    Retorna lista de paths dos arquivos extraídos.
    """
    os.makedirs(out_dir, exist_ok=True)
    try:
        with py7zr.SevenZipFile(arquivo_7z, mode="r") as z:
            z.extractall(path=out_dir)
    except Exception as e:
        print(f"[ERRO extração] {arquivo_7z}: {e}")
        return []
    arquivos = []
    for root, _, files in os.walk(out_dir):
        for f in files:
            arquivos.append(os.path.join(root, f))
    return arquivos



def processar_tipo_para_parquet_streaming(ano, tipo, base_path, output_parquet_local, sep=";", encoding="latin-1"):
    """
    Procura por arquivos extraídos que correspondam a CAGED{TIPO}{ANO}*
    e escreve em streaming para um único arquivo Parquet.
    """
    targets = []
    for root, _, files in os.walk(base_path):
        for fname in files:
            fname_up = fname.upper()
            if fname_up.startswith(f"CAGED{tipo}{ano}") and fname.lower().endswith((".txt", ".csv")):
                targets.append(os.path.join(root, fname))

    if not targets:
        print(f"[INFO] Nenhum arquivo encontrado para {ano} {tipo}")
        return False

    if os.path.exists(output_parquet_local):
        os.remove(output_parquet_local)

    writer = None
    schema = None

    for arq in sorted(targets):
        print(f" Lendo em chunks: {arq}")
        try:
            for chunk in pd.read_csv(arq, sep=sep, encoding=encoding, chunksize=200_000, low_memory=False):
                chunk.columns = [c.strip() for c in chunk.columns]

                # converte chunk para pyarrow table
                if writer is None:
                    table = pa.Table.from_pandas(chunk, preserve_index=False)
                    schema = table.schema
                    writer = pq.ParquetWriter(output_parquet_local, schema, compression="snappy")
                    writer.write_table(table)
                else:
                    # tenta converter para o mesmo schema; se faltar coluna, adiciona com NA
                    try:
                        table = pa.Table.from_pandas(chunk, schema=schema, preserve_index=False)
                    except Exception:
                        cols_target = [f.name for f in schema]
                        df2 = chunk.copy()
                        for c in cols_target:
                            if c not in df2.columns:
                                df2[c] = pd.NA
                        df2 = df2[cols_target]
                        table = pa.Table.from_pandas(df2, schema=schema, preserve_index=False)
                    writer.write_table(table)
        except Exception as e:
            print(f"[ERRO leitura {arq}] {e}")

    if writer is not None:
        writer.close()
        print(f"[OK] Parquet criado: {output_parquet_local}")
        return True
    else:
        print(f"[WARN] Nenhum chunk escrito para {ano} {tipo}")
        return False


def upload_to_gcs(local_file, bucket_name, remote_path):
    client = storage.Client()
    bucket = client.bucket(bucket_name)
    blob = bucket.blob(remote_path)
    blob.upload_from_filename(local_file)
    print(f"✅ Upload: gs://{bucket_name}/{remote_path}")

# %%
# ========================================
# 4. Pipeline
# ========================================
for ano in anos:
    print(f"\n==== PROCESSANDO ANO {ano} ====")
    for mes in range(1, 13):
        print(f"--> Mês {mes:02d}")
        arquivos_7z = baixar_arquivos(ano, mes)
        for arq in arquivos_7z:
            out_dir = os.path.join(BASE_PATH, os.path.basename(arq).replace(".7z", ""))
            if not os.path.exists(out_dir) or not os.listdir(out_dir):
                print(f"  Extraindo {os.path.basename(arq)} para {out_dir}")
                extrair_7z_para_pasta(arq, out_dir)
            else:
                print(f"  Já extraído: {out_dir}")

    for tipo in tipos:
        print(f"\n--- Juntando {ano} {tipo} em Parquet ---")
        local_parquet = os.path.join(BASE_PATH, f"{ano}{tipo}.parquet")
        ok = processar_tipo_para_parquet_streaming(ano, tipo, BASE_PATH, local_parquet)
        if ok:
            remote = f"caged/{ano}/{tipo}/{ano}{tipo}.parquet"
            upload_to_gcs(local_parquet, BUCKET_NAME, remote)
        else:
            print(f"[INFO] Nada para subir para {ano}/{tipo}")
# Out:
# ==== PROCESSANDO ANO 2020 ====
# --> Mês 01
# Baixando CAGEDMOV202001.7z ...
#   Extraindo CAGEDMOV202001.7z para /content/caged_data/CAGEDMOV202001
# --> Mês 02
# Baixando CAGEDFOR202002.7z ...
# Baixando CAGEDMOV202002.7z ...
#   Extraindo CAGEDFOR202002.7z para /content/caged_data/CAGEDFOR202002
#   Extraindo CAGEDMOV202002.7z para /content/caged_data/CAGEDMOV202002
# --> Mês 03
# Baixando CAGEDFOR202003.7z ...
# Baixando CAGEDMOV202003.7z ...
#   Extraindo CAGEDFOR202003.7z para /content/caged_data/CAGEDFOR202003
# [ERRO extração] /content/caged_data/CAGEDFOR202003.7z: Corrupt input data
#   Extraindo CAGEDMOV202003.7z para /content/caged_data/CAGEDMOV202003
# --> Mês 04
# Baixando CAGEDEXC202004.7z ...
# Baixando CAGEDFOR202004.7z ...
# Baixando CAGEDMOV202004.7z ...
#   Extraindo CAGEDEXC202004.7z para /content/caged_data/CAGEDEXC202004
#   Extraindo CAGEDFOR202004.7z para /content/caged_data/CAGEDFOR202004
#   Extraindo CAGEDMOV202004.7z para /content/caged_data/CAGEDMOV202004
# --> Mês 05
# Baixando CAGEDEXC202005.7z ...
# Baixando CAGEDFOR202005.7z ...
# Baixando CAGEDMOV202005.7z ...
#   Extraindo CAGEDEXC202005.7z para /content/caged_data/CAGEDEXC202005
#   Extraindo CAGEDFOR202005.7z para /content/caged_data/CAGEDFOR202005
#   Extraindo CAGEDMOV202005.7z para /content/caged_data/CAGEDMOV202005
# --> Mês 06
# Baixando CAGEDEXC202006.7z ...
# Baixando CAGEDFOR202006.7z ...
# Baixando CAGEDMOV202006.7z ...
#   Extraindo CAGEDEXC202006.7z para /content/caged_data/CAGEDEXC202006
#   Extraindo CAGEDFOR202006.7z para /content/caged_data/CAGEDFOR202006
#   Extraindo CAGEDMOV202006.7z para /content/caged_data/CAGEDMOV202006
# --> Mês 07
# Baixando CAGEDEXC202007.7z ...
# Baixando CAGEDFOR202007.7z ...
# Baixando CAGEDMOV202007.7z ...
#   Extraindo CAGEDEXC202007.7z para /content/caged_data/CAGEDEXC202007
#   Extraindo CAGEDFOR202007.7z para /content/caged_data/CAGEDFOR202007
#   Extraindo CAGEDMOV202007.7z para /content/caged_data/CAGEDMOV202007
# [ERRO extração] /content/caged_data/CAGEDMOV202007.7z: Corrupt input data
# --> Mês 08
# Baixando CAGEDEXC202008.7z ...
# Baixando CAGEDFOR202008.7z ...
# Baixando CAGEDMOV202008.7z ...
#   Extraindo CAGEDEXC202008.7z para /content/caged_data/CAGEDEXC202008
#   Extraindo CAGEDFOR202008.7z para /content/caged_data/CAGEDFOR202008
#   Extraindo CAGEDMOV202008.7z para /content/caged_data/CAGEDMOV202008
# --> Mês 09
# Baixando CAGEDEXC202009.7z ...
# Baixando CAGEDFOR202009.7z ...
# Baixando CAGEDMOV202009.7z ...
#   Extraindo CAGEDEXC202009.7z para /content/caged_data/CAGEDEXC202009
#   Extraindo CAGEDFOR202009.7z para /content/caged_data/CAGEDFOR202009
#   Extraindo CAGEDMOV202009.7z para /content/caged_data/CAGEDMOV202009
# --> Mês 10
# Baixando CAGEDEXC202010.7z ...
# Baixando CAGEDFOR202010.7z ...
# Baixando CAGEDMOV202010.7z ...
#   Extraindo CAGEDEXC202010.7z para /content/caged_data/CAGEDEXC202010
#   Extraindo CAGEDFOR202010.7z para /content/caged_data/CAGEDFOR202010
#   Extraindo CAGEDMOV202010.7z para /content/caged_data/CAGEDMOV202010
# --> Mês 11
# Baixando CAGEDEXC202011.7z ...
# Baixando CAGEDFOR202011.7z ...
# Baixando CAGEDMOV202011.7z ...
#   Extraindo CAGEDEXC202011.7z para /content/caged_data/CAGEDEXC202011
#   Extraindo CAGEDFOR202011.7z para /content/caged_data/CAGEDFOR202011
#   Extraindo CAGEDMOV202011.7z para /content/caged_data/CAGEDMOV202011
# --> Mês 12
# Baixando CAGEDEXC202012.7z ...
# Baixando CAGEDFOR202012.7z ...
# Baixando CAGEDMOV202012.7z ...
#   Extraindo CAGEDEXC202012.7z para /content/caged_data/CAGEDEXC202012
#   Extraindo CAGEDFOR202012.7z para /content/caged_data/CAGEDFOR202012
#   Extraindo CAGEDMOV202012.7z para /content/caged_data/CAGEDMOV202012
# [ERRO extração] /content/caged_data/CAGEDMOV202012.7z: Corrupt input data
#
# --- Juntando 2020 MOV em Parquet ---
#  Lendo em chunks: /content/caged_data/CAGEDMOV202001/CAGEDMOV202001.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202002/CAGEDMOV202002.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202003/CAGEDMOV202003.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202004/CAGEDMOV202004.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202005/CAGEDMOV202005.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202006/CAGEDMOV202006.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202007/CAGEDMOV202007.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202008/CAGEDMOV202008.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202009/CAGEDMOV202009.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202010/CAGEDMOV202010.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202011/CAGEDMOV202011.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202012/CAGEDMOV202012.txt
# [OK] Parquet criado: /content/caged_data/2020MOV.parquet
# ✅ Upload: gs://bucket_caged/caged/2020/MOV/2020MOV.parquet
#
# --- Juntando 2020 EXC em Parquet ---
#  Lendo em chunks: /content/caged_data/CAGEDEXC202004/CAGEDEXC202004.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202005/CAGEDEXC202005.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202006/CAGEDEXC202006.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202007/CAGEDEXC202007.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202008/CAGEDEXC202008.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202009/CAGEDEXC202009.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202010/CAGEDEXC202010.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202011/CAGEDEXC202011.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202012/CAGEDEXC202012.txt
# [OK] Parquet criado: /content/caged_data/2020EXC.parquet
# ✅ Upload: gs://bucket_caged/caged/2020/EXC/2020EXC.parquet
#
# --- Juntando 2020 FOR em Parquet ---
#  Lendo em chunks: /content/caged_data/CAGEDFOR202002/CAGEDFOR202002.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202003/CAGEDFOR202003.txt
# [ERRO leitura /content/caged_data/CAGEDFOR202003/CAGEDFOR202003.txt] No columns to parse from file
#  Lendo em chunks: /content/caged_data/CAGEDFOR202004/CAGEDFOR202004.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202005/CAGEDFOR202005.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202006/CAGEDFOR202006.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202007/CAGEDFOR202007.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202008/CAGEDFOR202008.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202009/CAGEDFOR202009.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202010/CAGEDFOR202010.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202011/CAGEDFOR202011.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202012/CAGEDFOR202012.txt
# [OK] Parquet criado: /content/caged_data/2020FOR.parquet
# ✅ Upload: gs://bucket_caged/caged/2020/FOR/2020FOR.parquet
#
# ==== PROCESSANDO ANO 2021 ====
# --> Mês 01
# Baixando CAGEDEXC202101.7z ...
# Baixando CAGEDFOR202101.7z ...
# Baixando CAGEDMOV202101.7z ...
#   Extraindo CAGEDEXC202101.7z para /content/caged_data/CAGEDEXC202101
#   Extraindo CAGEDFOR202101.7z para /content/caged_data/CAGEDFOR202101
#   Extraindo CAGEDMOV202101.7z para /content/caged_data/CAGEDMOV202101
# --> Mês 02
# Baixando CAGEDEXC202102.7z ...
# Baixando CAGEDFOR202102.7z ...
# Baixando CAGEDMOV202102.7z ...
#   Extraindo CAGEDEXC202102.7z para /content/caged_data/CAGEDEXC202102
#   Extraindo CAGEDFOR202102.7z para /content/caged_data/CAGEDFOR202102
#   Extraindo CAGEDMOV202102.7z para /content/caged_data/CAGEDMOV202102
# --> Mês 03
# Baixando CAGEDEXC202103.7z ...
# Baixando CAGEDFOR202103.7z ...
# Baixando CAGEDMOV202103.7z ...
#   Extraindo CAGEDEXC202103.7z para /content/caged_data/CAGEDEXC202103
#   Extraindo CAGEDFOR202103.7z para /content/caged_data/CAGEDFOR202103
#   Extraindo CAGEDMOV202103.7z para /content/caged_data/CAGEDMOV202103
# --> Mês 04
# Baixando CAGEDEXC202104.7z ...
# Baixando CAGEDFOR202104.7z ...
# Baixando CAGEDMOV202104.7z ...
#   Extraindo CAGEDEXC202104.7z para /content/caged_data/CAGEDEXC202104
#   Extraindo CAGEDFOR202104.7z para /content/caged_data/CAGEDFOR202104
#   Extraindo CAGEDMOV202104.7z para /content/caged_data/CAGEDMOV202104
# [ERRO extração] /content/caged_data/CAGEDMOV202104.7z: Corrupt input data
# --> Mês 05
# Baixando CAGEDEXC202105.7z ...
# Baixando CAGEDFOR202105.7z ...
# Baixando CAGEDMOV202105.7z ...
#   Extraindo CAGEDEXC202105.7z para /content/caged_data/CAGEDEXC202105
#   Extraindo CAGEDFOR202105.7z para /content/caged_data/CAGEDFOR202105
#   Extraindo CAGEDMOV202105.7z para /content/caged_data/CAGEDMOV202105
# [ERRO extração] /content/caged_data/CAGEDMOV202105.7z: Corrupt input data
# --> Mês 06
# Baixando CAGEDEXC202106.7z ...
# Baixando CAGEDFOR202106.7z ...
# Baixando CAGEDMOV202106.7z ...
#   Extraindo CAGEDEXC202106.7z para /content/caged_data/CAGEDEXC202106
#   Extraindo CAGEDFOR202106.7z para /content/caged_data/CAGEDFOR202106
#   Extraindo CAGEDMOV202106.7z para /content/caged_data/CAGEDMOV202106
# [ERRO extração] /content/caged_data/CAGEDMOV202106.7z: Corrupt input data
# --> Mês 07
# Baixando CAGEDEXC202107.7z ...
# Baixando CAGEDFOR202107.7z ...
# Baixando CAGEDMOV202107.7z ...
#   Extraindo CAGEDEXC202107.7z para /content/caged_data/CAGEDEXC202107
#   Extraindo CAGEDFOR202107.7z para /content/caged_data/CAGEDFOR202107
#   Extraindo CAGEDMOV202107.7z para /content/caged_data/CAGEDMOV202107
# [ERRO extração] /content/caged_data/CAGEDMOV202107.7z: Corrupt input data
# --> Mês 08
# Baixando CAGEDEXC202108.7z ...
# Baixando CAGEDFOR202108.7z ...
# Baixando CAGEDMOV202108.7z ...
#   Extraindo CAGEDEXC202108.7z para /content/caged_data/CAGEDEXC202108
#   Extraindo CAGEDFOR202108.7z para /content/caged_data/CAGEDFOR202108
#   Extraindo CAGEDMOV202108.7z para /content/caged_data/CAGEDMOV202108
# [ERRO extração] /content/caged_data/CAGEDMOV202108.7z: Corrupt input data
# --> Mês 09
# Baixando CAGEDEXC202109.7z ...
# Baixando CAGEDFOR202109.7z ...
# Baixando CAGEDMOV202109.7z ...
#   Extraindo CAGEDEXC202109.7z para /content/caged_data/CAGEDEXC202109
#   Extraindo CAGEDFOR202109.7z para /content/caged_data/CAGEDFOR202109
#   Extraindo CAGEDMOV202109.7z para /content/caged_data/CAGEDMOV202109
# [ERRO extração] /content/caged_data/CAGEDMOV202109.7z: Corrupt input data
# --> Mês 10
# Baixando CAGEDEXC202110.7z ...
# Baixando CAGEDFOR202110.7z ...
# Baixando CAGEDMOV202110.7z ...
#   Extraindo CAGEDEXC202110.7z para /content/caged_data/CAGEDEXC202110
#   Extraindo CAGEDFOR202110.7z para /content/caged_data/CAGEDFOR202110
#   Extraindo CAGEDMOV202110.7z para /content/caged_data/CAGEDMOV202110
# [ERRO extração] /content/caged_data/CAGEDMOV202110.7z: Corrupt input data
# --> Mês 11
# Baixando CAGEDEXC202111.7z ...
# Baixando CAGEDFOR202111.7z ...
# Baixando CAGEDMOV202111.7z ...
#   Extraindo CAGEDEXC202111.7z para /content/caged_data/CAGEDEXC202111
#   Extraindo CAGEDFOR202111.7z para /content/caged_data/CAGEDFOR202111
# [ERRO extração] /content/caged_data/CAGEDFOR202111.7z: Corrupt input data
#   Extraindo CAGEDMOV202111.7z para /content/caged_data/CAGEDMOV202111
# [ERRO extração] /content/caged_data/CAGEDMOV202111.7z: Corrupt input data
# --> Mês 12
# Baixando CAGEDEXC202112.7z ...
# Baixando CAGEDFOR202112.7z ...
# Baixando CAGEDMOV202112.7z ...
#   Extraindo CAGEDEXC202112.7z para /content/caged_data/CAGEDEXC202112
#   Extraindo CAGEDFOR202112.7z para /content/caged_data/CAGEDFOR202112
#   Extraindo CAGEDMOV202112.7z para /content/caged_data/CAGEDMOV202112
# [ERRO extração] /content/caged_data/CAGEDMOV202112.7z: Corrupt input data
#
# --- Juntando 2021 MOV em Parquet ---
#  Lendo em chunks: /content/caged_data/CAGEDMOV202101/CAGEDMOV202101.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202102/CAGEDMOV202102.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202103/CAGEDMOV202103.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202104/CAGEDMOV202104.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202105/CAGEDMOV202105.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202106/CAGEDMOV202106.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202107/CAGEDMOV202107.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202108/CAGEDMOV202108.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202109/CAGEDMOV202109.txt
# [ERRO leitura /content/caged_data/CAGEDMOV202109/CAGEDMOV202109.txt] ("Could not convert '139399' with type str: tried to convert to int64", 'Conversion failed for column subclasse with type object')
#  Lendo em chunks: /content/caged_data/CAGEDMOV202110/CAGEDMOV202110.txt
# [ERRO leitura /content/caged_data/CAGEDMOV202110/CAGEDMOV202110.txt] Error tokenizing data. C error: Expected 28 fields in line 1071307, saw 59
#
#  Lendo em chunks: /content/caged_data/CAGEDMOV202111/CAGEDMOV202111.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202112/CAGEDMOV202112.txt
# [OK] Parquet criado: /content/caged_data/2021MOV.parquet
# ✅ Upload: gs://bucket_caged/caged/2021/MOV/2021MOV.parquet
#
# --- Juntando 2021 EXC em Parquet ---
#  Lendo em chunks: /content/caged_data/CAGEDEXC202101/CAGEDEXC202101.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202102/CAGEDEXC202102.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202103/CAGEDEXC202103.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202104/CAGEDEXC202104.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202105/CAGEDEXC202105.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202106/CAGEDEXC202106.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202107/CAGEDEXC202107.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202108/CAGEDEXC202108.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202109/CAGEDEXC202109.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202110/CAGEDEXC202110.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202111/CAGEDEXC202111.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202112/CAGEDEXC202112.txt
# [OK] Parquet criado: /content/caged_data/2021EXC.parquet
# ✅ Upload: gs://bucket_caged/caged/2021/EXC/2021EXC.parquet
#
# --- Juntando 2021 FOR em Parquet ---
#  Lendo em chunks: /content/caged_data/CAGEDFOR202101/CAGEDFOR202101.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202102/CAGEDFOR202102.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202103/CAGEDFOR202103.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202104/CAGEDFOR202104.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202105/CAGEDFOR202105.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202106/CAGEDFOR202106.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202107/CAGEDFOR202107.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202108/CAGEDFOR202108.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202109/CAGEDFOR202109.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202110/CAGEDFOR202110.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202111/CAGEDFOR202111.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202112/CAGEDFOR202112.txt
# [OK] Parquet criado: /content/caged_data/2021FOR.parquet
# ✅ Upload: gs://bucket_caged/caged/2021/FOR/2021FOR.parquet
#
# ==== PROCESSANDO ANO 2022 ====
# --> Mês 01
# Baixando CAGEDEXC202201.7z ...
# Baixando CAGEDFOR202201.7z ...
# Baixando CAGEDMOV202201.7z ...
#   Extraindo CAGEDEXC202201.7z para /content/caged_data/CAGEDEXC202201
#   Extraindo CAGEDFOR202201.7z para /content/caged_data/CAGEDFOR202201
# [ERRO extração] /content/caged_data/CAGEDFOR202201.7z: Corrupt input data
#   Extraindo CAGEDMOV202201.7z para /content/caged_data/CAGEDMOV202201
# --> Mês 02
# Baixando CAGEDEXC202202.7z ...
# Baixando CAGEDFOR202202.7z ...
# Baixando CAGEDMOV202202.7z ...
#   Extraindo CAGEDEXC202202.7z para /content/caged_data/CAGEDEXC202202
#   Extraindo CAGEDFOR202202.7z para /content/caged_data/CAGEDFOR202202
#   Extraindo CAGEDMOV202202.7z para /content/caged_data/CAGEDMOV202202
# [ERRO extração] /content/caged_data/CAGEDMOV202202.7z: Corrupt input data
# --> Mês 03
# Baixando CAGEDEXC202203.7z ...
# Baixando CAGEDFOR202203.7z ...
# Baixando CAGEDMOV202203.7z ...
#   Extraindo CAGEDEXC202203.7z para /content/caged_data/CAGEDEXC202203
#   Extraindo CAGEDFOR202203.7z para /content/caged_data/CAGEDFOR202203
#   Extraindo CAGEDMOV202203.7z para /content/caged_data/CAGEDMOV202203
# [ERRO extração] /content/caged_data/CAGEDMOV202203.7z: Corrupt input data
# --> Mês 04
# Baixando CAGEDEXC202204.7z ...
# Baixando CAGEDFOR202204.7z ...
# Baixando CAGEDMOV202204.7z ...
#   Extraindo CAGEDEXC202204.7z para /content/caged_data/CAGEDEXC202204
#   Extraindo CAGEDFOR202204.7z para /content/caged_data/CAGEDFOR202204
# [ERRO extração] /content/caged_data/CAGEDFOR202204.7z: Corrupt input data
#   Extraindo CAGEDMOV202204.7z para /content/caged_data/CAGEDMOV202204
# [ERRO extração] /content/caged_data/CAGEDMOV202204.7z: Corrupt input data
# --> Mês 05
# Baixando CAGEDEXC202205.7z ...
# Baixando CAGEDFOR202205.7z ...
# Baixando CAGEDMOV202205.7z ...
#   Extraindo CAGEDEXC202205.7z para /content/caged_data/CAGEDEXC202205
#   Extraindo CAGEDFOR202205.7z para /content/caged_data/CAGEDFOR202205
#   Extraindo CAGEDMOV202205.7z para /content/caged_data/CAGEDMOV202205
# --> Mês 06
# Baixando CAGEDEXC202206.7z ...
# Baixando CAGEDFOR202206.7z ...
# Baixando CAGEDMOV202206.7z ...
#   Extraindo CAGEDEXC202206.7z para /content/caged_data/CAGEDEXC202206
#   Extraindo CAGEDFOR202206.7z para /content/caged_data/CAGEDFOR202206
#   Extraindo CAGEDMOV202206.7z para /content/caged_data/CAGEDMOV202206
# [ERRO extração] /content/caged_data/CAGEDMOV202206.7z: Corrupt input data
# --> Mês 07
# Baixando CAGEDEXC202207.7z ...
# Baixando CAGEDFOR202207.7z ...
# Baixando CAGEDMOV202207.7z ...
#   Extraindo CAGEDEXC202207.7z para /content/caged_data/CAGEDEXC202207
#   Extraindo CAGEDFOR202207.7z para /content/caged_data/CAGEDFOR202207
#   Extraindo CAGEDMOV202207.7z para /content/caged_data/CAGEDMOV202207
# [ERRO extração] /content/caged_data/CAGEDMOV202207.7z: Corrupt input data
# --> Mês 08
# Baixando CAGEDEXC202208.7z ...
# Baixando CAGEDFOR202208.7z ...
# Baixando CAGEDMOV202208.7z ...
#   Extraindo CAGEDEXC202208.7z para /content/caged_data/CAGEDEXC202208
#   Extraindo CAGEDFOR202208.7z para /content/caged_data/CAGEDFOR202208
#   Extraindo CAGEDMOV202208.7z para /content/caged_data/CAGEDMOV202208
# --> Mês 09
# Baixando CAGEDEXC202209.7z ...
# Baixando CAGEDFOR202209.7z ...
# Baixando CAGEDMOV202209.7z ...
#   Extraindo CAGEDEXC202209.7z para /content/caged_data/CAGEDEXC202209
#   Extraindo CAGEDFOR202209.7z para /content/caged_data/CAGEDFOR202209
#   Extraindo CAGEDMOV202209.7z para /content/caged_data/CAGEDMOV202209
# --> Mês 10
# Baixando CAGEDEXC202210.7z ...
# Baixando CAGEDFOR202210.7z ...
# Baixando CAGEDMOV202210.7z ...
#   Extraindo CAGEDEXC202210.7z para /content/caged_data/CAGEDEXC202210
#   Extraindo CAGEDFOR202210.7z para /content/caged_data/CAGEDFOR202210
#   Extraindo CAGEDMOV202210.7z para /content/caged_data/CAGEDMOV202210
# --> Mês 11
# Baixando CAGEDEXC202211.7z ...
# Baixando CAGEDFOR202211.7z ...
# Baixando CAGEDMOV202211.7z ...
#   Extraindo CAGEDEXC202211.7z para /content/caged_data/CAGEDEXC202211
#   Extraindo CAGEDFOR202211.7z para /content/caged_data/CAGEDFOR202211
#   Extraindo CAGEDMOV202211.7z para /content/caged_data/CAGEDMOV202211
# --> Mês 12
# Baixando CAGEDEXC202212.7z ...
# Baixando CAGEDFOR202212.7z ...
# Baixando CAGEDMOV202212.7z ...
#   Extraindo CAGEDEXC202212.7z para /content/caged_data/CAGEDEXC202212
#   Extraindo CAGEDFOR202212.7z para /content/caged_data/CAGEDFOR202212
#   Extraindo CAGEDMOV202212.7z para /content/caged_data/CAGEDMOV202212
#
# --- Juntando 2022 MOV em Parquet ---
#  Lendo em chunks: /content/caged_data/CAGEDMOV202201/CAGEDMOV202201.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202202/CAGEDMOV202202.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202203/CAGEDMOV202203.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202204/CAGEDMOV202204.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202205/CAGEDMOV202205.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202206/CAGEDMOV202206.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202207/CAGEDMOV202207.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202208/CAGEDMOV202208.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202209/CAGEDMOV202209.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202210/CAGEDMOV202210.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202211/CAGEDMOV202211.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202212/CAGEDMOV202212.txt
# [OK] Parquet criado: /content/caged_data/2022MOV.parquet
# ✅ Upload: gs://bucket_caged/caged/2022/MOV/2022MOV.parquet
#
# --- Juntando 2022 EXC em Parquet ---
#  Lendo em chunks: /content/caged_data/CAGEDEXC202201/CAGEDEXC202201.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202202/CAGEDEXC202202.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202203/CAGEDEXC202203.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202204/CAGEDEXC202204.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202205/CAGEDEXC202205.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202206/CAGEDEXC202206.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202207/CAGEDEXC202207.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202208/CAGEDEXC202208.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202209/CAGEDEXC202209.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202210/CAGEDEXC202210.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202211/CAGEDEXC202211.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202212/CAGEDEXC202212.txt
# [OK] Parquet criado: /content/caged_data/2022EXC.parquet
# ✅ Upload: gs://bucket_caged/caged/2022/EXC/2022EXC.parquet
#
# --- Juntando 2022 FOR em Parquet ---
#  Lendo em chunks: /content/caged_data/CAGEDFOR202201/CAGEDFOR202201.txt
# [ERRO leitura /content/caged_data/CAGEDFOR202201/CAGEDFOR202201.txt] No columns to parse from file
#  Lendo em chunks: /content/caged_data/CAGEDFOR202202/CAGEDFOR202202.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202203/CAGEDFOR202203.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202204/CAGEDFOR202204.txt
# [ERRO leitura /content/caged_data/CAGEDFOR202204/CAGEDFOR202204.txt] No columns to parse from file
#  Lendo em chunks: /content/caged_data/CAGEDFOR202205/CAGEDFOR202205.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202206/CAGEDFOR202206.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202207/CAGEDFOR202207.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202208/CAGEDFOR202208.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202209/CAGEDFOR202209.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202210/CAGEDFOR202210.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202211/CAGEDFOR202211.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202212/CAGEDFOR202212.txt
# [OK] Parquet criado: /content/caged_data/2022FOR.parquet
# ✅ Upload: gs://bucket_caged/caged/2022/FOR/2022FOR.parquet
#
# ==== PROCESSANDO ANO 2023 ====
# --> Mês 01
# Baixando CAGEDEXC202301.7z ...
# Baixando CAGEDFOR202301.7z ...
# Baixando CAGEDMOV202301.7z ...
#   Extraindo CAGEDEXC202301.7z para /content/caged_data/CAGEDEXC202301
#   Extraindo CAGEDFOR202301.7z para /content/caged_data/CAGEDFOR202301
#   Extraindo CAGEDMOV202301.7z para /content/caged_data/CAGEDMOV202301
# --> Mês 02
# Baixando CAGEDEXC202302.7z ...
# Baixando CAGEDFOR202302.7z ...
# Baixando CAGEDMOV202302.7z ...
#   Extraindo CAGEDEXC202302.7z para /content/caged_data/CAGEDEXC202302
#   Extraindo CAGEDFOR202302.7z para /content/caged_data/CAGEDFOR202302
#   Extraindo CAGEDMOV202302.7z para /content/caged_data/CAGEDMOV202302
# --> Mês 03
# Baixando CAGEDEXC202303.7z ...
# Baixando CAGEDFOR202303.7z ...
# Baixando CAGEDMOV202303.7z ...
#   Extraindo CAGEDEXC202303.7z para /content/caged_data/CAGEDEXC202303
#   Extraindo CAGEDFOR202303.7z para /content/caged_data/CAGEDFOR202303
#   Extraindo CAGEDMOV202303.7z para /content/caged_data/CAGEDMOV202303
# --> Mês 04
# Baixando CAGEDEXC202304.7z ...
# Baixando CAGEDFOR202304.7z ...
# Baixando CAGEDMOV202304.7z ...
#   Extraindo CAGEDEXC202304.7z para /content/caged_data/CAGEDEXC202304
#   Extraindo CAGEDFOR202304.7z para /content/caged_data/CAGEDFOR202304
#   Extraindo CAGEDMOV202304.7z para /content/caged_data/CAGEDMOV202304
# --> Mês 05
# Baixando CAGEDEXC202305.7z ...
# Baixando CAGEDFOR202305.7z ...
# Baixando CAGEDMOV202305.7z ...
#   Extraindo CAGEDEXC202305.7z para /content/caged_data/CAGEDEXC202305
#   Extraindo CAGEDFOR202305.7z para /content/caged_data/CAGEDFOR202305
#   Extraindo CAGEDMOV202305.7z para /content/caged_data/CAGEDMOV202305
# --> Mês 06
# Baixando CAGEDEXC202306.7z ...
# Baixando CAGEDFOR202306.7z ...
# Baixando CAGEDMOV202306.7z ...
#   Extraindo CAGEDEXC202306.7z para /content/caged_data/CAGEDEXC202306
#   Extraindo CAGEDFOR202306.7z para /content/caged_data/CAGEDFOR202306
#   Extraindo CAGEDMOV202306.7z para /content/caged_data/CAGEDMOV202306
# --> Mês 07
# Baixando CAGEDEXC202307.7z ...
# Baixando CAGEDFOR202307.7z ...
# Baixando CAGEDMOV202307.7z ...
#   Extraindo CAGEDEXC202307.7z para /content/caged_data/CAGEDEXC202307
#   Extraindo CAGEDFOR202307.7z para /content/caged_data/CAGEDFOR202307
#   Extraindo CAGEDMOV202307.7z para /content/caged_data/CAGEDMOV202307
# --> Mês 08
# Baixando CAGEDEXC202308.7z ...
# Baixando CAGEDFOR202308.7z ...
# Baixando CAGEDMOV202308.7z ...
#   Extraindo CAGEDEXC202308.7z para /content/caged_data/CAGEDEXC202308
#   Extraindo CAGEDFOR202308.7z para /content/caged_data/CAGEDFOR202308
#   Extraindo CAGEDMOV202308.7z para /content/caged_data/CAGEDMOV202308
# --> Mês 09
# Baixando CAGEDEXC202309.7z ...
# Baixando CAGEDFOR202309.7z ...
# Baixando CAGEDMOV202309.7z ...
#   Extraindo CAGEDEXC202309.7z para /content/caged_data/CAGEDEXC202309
#   Extraindo CAGEDFOR202309.7z para /content/caged_data/CAGEDFOR202309
#   Extraindo CAGEDMOV202309.7z para /content/caged_data/CAGEDMOV202309
# --> Mês 10
# Baixando CAGEDEXC202310.7z ...
# Baixando CAGEDFOR202310.7z ...
# Baixando CAGEDMOV202310.7z ...
#   Extraindo CAGEDEXC202310.7z para /content/caged_data/CAGEDEXC202310
#   Extraindo CAGEDFOR202310.7z para /content/caged_data/CAGEDFOR202310
#   Extraindo CAGEDMOV202310.7z para /content/caged_data/CAGEDMOV202310
# --> Mês 11
# Baixando CAGEDEXC202311.7z ...
# Baixando CAGEDFOR202311.7z ...
# Baixando CAGEDMOV202311.7z ...
#   Extraindo CAGEDEXC202311.7z para /content/caged_data/CAGEDEXC202311
#   Extraindo CAGEDFOR202311.7z para /content/caged_data/CAGEDFOR202311
#   Extraindo CAGEDMOV202311.7z para /content/caged_data/CAGEDMOV202311
# --> Mês 12
# Baixando CAGEDEXC202312.7z ...
# Baixando CAGEDFOR202312.7z ...
# Baixando CAGEDMOV202312.7z ...
#   Extraindo CAGEDEXC202312.7z para /content/caged_data/CAGEDEXC202312
#   Extraindo CAGEDFOR202312.7z para /content/caged_data/CAGEDFOR202312
#   Extraindo CAGEDMOV202312.7z para /content/caged_data/CAGEDMOV202312
#
# --- Juntando 2023 MOV em Parquet ---
#  Lendo em chunks: /content/caged_data/CAGEDMOV202301/CAGEDMOV202301.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202302/CAGEDMOV202302.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202303/CAGEDMOV202303.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202304/CAGEDMOV202304.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202305/CAGEDMOV202305.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202306/CAGEDMOV202306.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202307/CAGEDMOV202307.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202308/CAGEDMOV202308.txt
# [ERRO leitura /content/caged_data/CAGEDMOV202308/CAGEDMOV202308.txt] ('Expected a string or bytes dtype, got float64', 'Conversion failed for column horascontratuais with type float64')
#  Lendo em chunks: /content/caged_data/CAGEDMOV202309/CAGEDMOV202309.txt
# [ERRO leitura /content/caged_data/CAGEDMOV202309/CAGEDMOV202309.txt] ('Expected a string or bytes dtype, got float64', 'Conversion failed for column horascontratuais with type float64')
#  Lendo em chunks: /content/caged_data/CAGEDMOV202310/CAGEDMOV202310.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202311/CAGEDMOV202311.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202312/CAGEDMOV202312.txt
# [OK] Parquet criado: /content/caged_data/2023MOV.parquet
# ✅ Upload: gs://bucket_caged/caged/2023/MOV/2023MOV.parquet
#
# --- Juntando 2023 EXC em Parquet ---
#  Lendo em chunks: /content/caged_data/CAGEDEXC202301/CAGEDEXC202301.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202302/CAGEDEXC202302.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202303/CAGEDEXC202303.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202304/CAGEDEXC202304.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202305/CAGEDEXC202305.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202306/CAGEDEXC202306.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202307/CAGEDEXC202307.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202308/CAGEDEXC202308.txt
# [ERRO leitura /content/caged_data/CAGEDEXC202308/CAGEDEXC202308.txt] ('Expected a string or bytes dtype, got float64', 'Conversion failed for column horascontratuais with type float64')
#  Lendo em chunks: /content/caged_data/CAGEDEXC202309/CAGEDEXC202309.txt
# [ERRO leitura /content/caged_data/CAGEDEXC202309/CAGEDEXC202309.txt] ('Expected a string or bytes dtype, got float64', 'Conversion failed for column horascontratuais with type float64')
#  Lendo em chunks: /content/caged_data/CAGEDEXC202310/CAGEDEXC202310.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202311/CAGEDEXC202311.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202312/CAGEDEXC202312.txt
# [OK] Parquet criado: /content/caged_data/2023EXC.parquet
# ✅ Upload: gs://bucket_caged/caged/2023/EXC/2023EXC.parquet
#
# --- Juntando 2023 FOR em Parquet ---
#  Lendo em chunks: /content/caged_data/CAGEDFOR202301/CAGEDFOR202301.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202302/CAGEDFOR202302.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202303/CAGEDFOR202303.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202304/CAGEDFOR202304.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202305/CAGEDFOR202305.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202306/CAGEDFOR202306.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202307/CAGEDFOR202307.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202308/CAGEDFOR202308.txt
# [ERRO leitura /content/caged_data/CAGEDFOR202308/CAGEDFOR202308.txt] ('Expected a string or bytes dtype, got float64', 'Conversion failed for column horascontratuais with type float64')
#  Lendo em chunks: /content/caged_data/CAGEDFOR202309/CAGEDFOR202309.txt
# [ERRO leitura /content/caged_data/CAGEDFOR202309/CAGEDFOR202309.txt] ('Expected a string or bytes dtype, got float64', 'Conversion failed for column horascontratuais with type float64')
#  Lendo em chunks: /content/caged_data/CAGEDFOR202310/CAGEDFOR202310.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202311/CAGEDFOR202311.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202312/CAGEDFOR202312.txt
# [OK] Parquet criado: /content/caged_data/2023FOR.parquet
# ✅ Upload: gs://bucket_caged/caged/2023/FOR/2023FOR.parquet
#
# ==== PROCESSANDO ANO 2024 ====
# --> Mês 01
# Baixando CAGEDEXC202401.7z ...
# Baixando CAGEDFOR202401.7z ...
# Baixando CAGEDMOV202401.7z ...
#   Extraindo CAGEDEXC202401.7z para /content/caged_data/CAGEDEXC202401
#   Extraindo CAGEDFOR202401.7z para /content/caged_data/CAGEDFOR202401
#   Extraindo CAGEDMOV202401.7z para /content/caged_data/CAGEDMOV202401
# --> Mês 02
# Baixando CAGEDEXC202402.7z ...
# Baixando CAGEDFOR202402.7z ...
# Baixando CAGEDMOV202402.7z ...
#   Extraindo CAGEDEXC202402.7z para /content/caged_data/CAGEDEXC202402
#   Extraindo CAGEDFOR202402.7z para /content/caged_data/CAGEDFOR202402
#   Extraindo CAGEDMOV202402.7z para /content/caged_data/CAGEDMOV202402
# --> Mês 03
# Baixando CAGEDEXC202403.7z ...
# Baixando CAGEDFOR202403.7z ...
# Baixando CAGEDMOV202403.7z ...
#   Extraindo CAGEDEXC202403.7z para /content/caged_data/CAGEDEXC202403
#   Extraindo CAGEDFOR202403.7z para /content/caged_data/CAGEDFOR202403
#   Extraindo CAGEDMOV202403.7z para /content/caged_data/CAGEDMOV202403
# --> Mês 04
# Baixando CAGEDEXC202404.7z ...
# Baixando CAGEDFOR202404.7z ...
# Baixando CAGEDMOV202404.7z ...
#   Extraindo CAGEDEXC202404.7z para /content/caged_data/CAGEDEXC202404
#   Extraindo CAGEDFOR202404.7z para /content/caged_data/CAGEDFOR202404
#   Extraindo CAGEDMOV202404.7z para /content/caged_data/CAGEDMOV202404
# --> Mês 05
# Baixando CAGEDEXC202405.7z ...
# Baixando CAGEDFOR202405.7z ...
# Baixando CAGEDMOV202405.7z ...
#   Extraindo CAGEDEXC202405.7z para /content/caged_data/CAGEDEXC202405
#   Extraindo CAGEDFOR202405.7z para /content/caged_data/CAGEDFOR202405
#   Extraindo CAGEDMOV202405.7z para /content/caged_data/CAGEDMOV202405
# --> Mês 06
# Baixando CAGEDEXC202406.7z ...
# Baixando CAGEDFOR202406.7z ...
# Baixando CAGEDMOV202406.7z ...
#   Extraindo CAGEDEXC202406.7z para /content/caged_data/CAGEDEXC202406
#   Extraindo CAGEDFOR202406.7z para /content/caged_data/CAGEDFOR202406
#   Extraindo CAGEDMOV202406.7z para /content/caged_data/CAGEDMOV202406
# --> Mês 07
# Baixando CAGEDEXC202407.7z ...
# Baixando CAGEDFOR202407.7z ...
# Baixando CAGEDMOV202407.7z ...
#   Extraindo CAGEDEXC202407.7z para /content/caged_data/CAGEDEXC202407
#   Extraindo CAGEDFOR202407.7z para /content/caged_data/CAGEDFOR202407
#   Extraindo CAGEDMOV202407.7z para /content/caged_data/CAGEDMOV202407
# --> Mês 08
# Baixando CAGEDEXC202408.7z ...
# Baixando CAGEDFOR202408.7z ...
# Baixando CAGEDMOV202408.7z ...
#   Extraindo CAGEDEXC202408.7z para /content/caged_data/CAGEDEXC202408
#   Extraindo CAGEDFOR202408.7z para /content/caged_data/CAGEDFOR202408
#   Extraindo CAGEDMOV202408.7z para /content/caged_data/CAGEDMOV202408
# --> Mês 09
# Baixando CAGEDEXC202409.7z ...
# Baixando CAGEDFOR202409.7z ...
# Baixando CAGEDMOV202409.7z ...
#   Extraindo CAGEDEXC202409.7z para /content/caged_data/CAGEDEXC202409
#   Extraindo CAGEDFOR202409.7z para /content/caged_data/CAGEDFOR202409
#   Extraindo CAGEDMOV202409.7z para /content/caged_data/CAGEDMOV202409
# --> Mês 10
# Baixando CAGEDEXC202410.7z ...
# Baixando CAGEDFOR202410.7z ...
# Baixando CAGEDMOV202410.7z ...
#   Extraindo CAGEDEXC202410.7z para /content/caged_data/CAGEDEXC202410
#   Extraindo CAGEDFOR202410.7z para /content/caged_data/CAGEDFOR202410
#   Extraindo CAGEDMOV202410.7z para /content/caged_data/CAGEDMOV202410
# --> Mês 11
# Baixando CAGEDEXC202411.7z ...
# Baixando CAGEDFOR202411.7z ...
# Baixando CAGEDMOV202411.7z ...
#   Extraindo CAGEDEXC202411.7z para /content/caged_data/CAGEDEXC202411
#   Extraindo CAGEDFOR202411.7z para /content/caged_data/CAGEDFOR202411
#   Extraindo CAGEDMOV202411.7z para /content/caged_data/CAGEDMOV202411
# --> Mês 12
# Baixando CAGEDEXC202412.7z ...
# Baixando CAGEDFOR202412.7z ...
# Baixando CAGEDMOV202412.7z ...
#   Extraindo CAGEDEXC202412.7z para /content/caged_data/CAGEDEXC202412
#   Extraindo CAGEDFOR202412.7z para /content/caged_data/CAGEDFOR202412
#   Extraindo CAGEDMOV202412.7z para /content/caged_data/CAGEDMOV202412
#
# --- Juntando 2024 MOV em Parquet ---
#  Lendo em chunks: /content/caged_data/CAGEDMOV202401/CAGEDMOV202401.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202402/CAGEDMOV202402.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202403/CAGEDMOV202403.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202404/CAGEDMOV202404.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202405/CAGEDMOV202405.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202406/CAGEDMOV202406.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202407/CAGEDMOV202407.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202408/CAGEDMOV202408.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202409/CAGEDMOV202409.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202410/CAGEDMOV202410.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202411/CAGEDMOV202411.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202412/CAGEDMOV202412.txt
# [OK] Parquet criado: /content/caged_data/2024MOV.parquet
# ✅ Upload: gs://bucket_caged/caged/2024/MOV/2024MOV.parquet
#
# --- Juntando 2024 EXC em Parquet ---
#  Lendo em chunks: /content/caged_data/CAGEDEXC202401/CAGEDEXC202401.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202402/CAGEDEXC202402.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202403/CAGEDEXC202403.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202404/CAGEDEXC202404.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202405/CAGEDEXC202405.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202406/CAGEDEXC202406.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202407/CAGEDEXC202407.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202408/CAGEDEXC202408.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202409/CAGEDEXC202409.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202410/CAGEDEXC202410.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202411/CAGEDEXC202411.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202412/CAGEDEXC202412.txt
# [OK] Parquet criado: /content/caged_data/2024EXC.parquet
# ✅ Upload: gs://bucket_caged/caged/2024/EXC/2024EXC.parquet
#
# --- Juntando 2024 FOR em Parquet ---
#  Lendo em chunks: /content/caged_data/CAGEDFOR202401/CAGEDFOR202401.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202402/CAGEDFOR202402.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202403/CAGEDFOR202403.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202404/CAGEDFOR202404.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202405/CAGEDFOR202405.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202406/CAGEDFOR202406.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202407/CAGEDFOR202407.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202408/CAGEDFOR202408.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202409/CAGEDFOR202409.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202410/CAGEDFOR202410.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202411/CAGEDFOR202411.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202412/CAGEDFOR202412.txt
# [OK] Parquet criado: /content/caged_data/2024FOR.parquet
# ✅ Upload: gs://bucket_caged/caged/2024/FOR/2024FOR.parquet
#
# ==== PROCESSANDO ANO 2025 ====
# --> Mês 01
# Baixando CAGEDEXC202501.7z ...
# Baixando CAGEDFOR202501.7z ...
# Baixando CAGEDMOV202501.7z ...
#   Extraindo CAGEDEXC202501.7z para /content/caged_data/CAGEDEXC202501
#   Extraindo CAGEDFOR202501.7z para /content/caged_data/CAGEDFOR202501
#   Extraindo CAGEDMOV202501.7z para /content/caged_data/CAGEDMOV202501
# --> Mês 02
# Baixando CAGEDEXC202502.7z ...
# Baixando CAGEDFOR202502.7z ...
# Baixando CAGEDMOV202502.7z ...
#   Extraindo CAGEDEXC202502.7z para /content/caged_data/CAGEDEXC202502
#   Extraindo CAGEDFOR202502.7z para /content/caged_data/CAGEDFOR202502
#   Extraindo CAGEDMOV202502.7z para /content/caged_data/CAGEDMOV202502
# --> Mês 03
# Baixando CAGEDEXC202503.7z ...
# Baixando CAGEDFOR202503.7z ...
# Baixando CAGEDMOV202503.7z ...
#   Extraindo CAGEDEXC202503.7z para /content/caged_data/CAGEDEXC202503
#   Extraindo CAGEDFOR202503.7z para /content/caged_data/CAGEDFOR202503
#   Extraindo CAGEDMOV202503.7z para /content/caged_data/CAGEDMOV202503
# --> Mês 04
# Baixando CAGEDEXC202504.7z ...
# Baixando CAGEDFOR202504.7z ...
# Baixando CAGEDMOV202504.7z ...
#   Extraindo CAGEDEXC202504.7z para /content/caged_data/CAGEDEXC202504
#   Extraindo CAGEDFOR202504.7z para /content/caged_data/CAGEDFOR202504
#   Extraindo CAGEDMOV202504.7z para /content/caged_data/CAGEDMOV202504
# --> Mês 05
# Baixando CAGEDEXC202505.7z ...
# Baixando CAGEDFOR202505.7z ...
# Baixando CAGEDMOV202505.7z ...
#   Extraindo CAGEDEXC202505.7z para /content/caged_data/CAGEDEXC202505
#   Extraindo CAGEDFOR202505.7z para /content/caged_data/CAGEDFOR202505
#   Extraindo CAGEDMOV202505.7z para /content/caged_data/CAGEDMOV202505
# --> Mês 06
# Baixando CAGEDEXC202506.7z ...
# Baixando CAGEDFOR202506.7z ...
# Baixando CAGEDMOV202506.7z ...
#   Extraindo CAGEDEXC202506.7z para /content/caged_data/CAGEDEXC202506
#   Extraindo CAGEDFOR202506.7z para /content/caged_data/CAGEDFOR202506
#   Extraindo CAGEDMOV202506.7z para /content/caged_data/CAGEDMOV202506
# --> Mês 07
# Baixando CAGEDEXC202507.7z ...
# Baixando CAGEDFOR202507.7z ...
# Baixando CAGEDMOV202507.7z ...
#   Extraindo CAGEDEXC202507.7z para /content/caged_data/CAGEDEXC202507
#   Extraindo CAGEDFOR202507.7z para /content/caged_data/CAGEDFOR202507
#   Extraindo CAGEDMOV202507.7z para /content/caged_data/CAGEDMOV202507
# --> Mês 08
# [WARN] Pasta não encontrada: pdet/microdados/NOVO CAGED/2025/202508
# --> Mês 09
# [WARN] Pasta não encontrada: pdet/microdados/NOVO CAGED/2025/202509
# --> Mês 10
# [WARN] Pasta não encontrada: pdet/microdados/NOVO CAGED/2025/202510
# --> Mês 11
# [WARN] Pasta não encontrada: pdet/microdados/NOVO CAGED/2025/202511
# --> Mês 12
# [WARN] Pasta não encontrada: pdet/microdados/NOVO CAGED/2025/202512
#
# --- Juntando 2025 MOV em Parquet ---
#  Lendo em chunks: /content/caged_data/CAGEDMOV202501/CAGEDMOV202501.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202502/CAGEDMOV202502.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202503/CAGEDMOV202503.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202504/CAGEDMOV202504.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202505/CAGEDMOV202505.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202506/CAGEDMOV202506.txt
#  Lendo em chunks: /content/caged_data/CAGEDMOV202507/CAGEDMOV202507.txt
# [OK] Parquet criado: /content/caged_data/2025MOV.parquet
# ✅ Upload: gs://bucket_caged/caged/2025/MOV/2025MOV.parquet
#
# --- Juntando 2025 EXC em Parquet ---
#  Lendo em chunks: /content/caged_data/CAGEDEXC202501/CAGEDEXC202501.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202502/CAGEDEXC202502.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202503/CAGEDEXC202503.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202504/CAGEDEXC202504.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202505/CAGEDEXC202505.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202506/CAGEDEXC202506.txt
#  Lendo em chunks: /content/caged_data/CAGEDEXC202507/CAGEDEXC202507.txt
# [OK] Parquet criado: /content/caged_data/2025EXC.parquet
# ✅ Upload: gs://bucket_caged/caged/2025/EXC/2025EXC.parquet
#
# --- Juntando 2025 FOR em Parquet ---
#  Lendo em chunks: /content/caged_data/CAGEDFOR202501/CAGEDFOR202501.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202502/CAGEDFOR202502.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202503/CAGEDFOR202503.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202504/CAGEDFOR202504.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202505/CAGEDFOR202505.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202506/CAGEDFOR202506.txt
#  Lendo em chunks: /content/caged_data/CAGEDFOR202507/CAGEDFOR202507.txt
# [OK] Parquet criado: /content/caged_data/2025FOR.parquet
# ✅ Upload: gs://bucket_caged/caged/2025/FOR/2025FOR.parquet
